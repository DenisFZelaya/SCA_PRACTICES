# %%
from rembg import remove
from PIL import Image

input_path = 'img.jpg'
output_path = 'img2.png'

inp = Image.open(input_path)
output = remove(inp)
output.save(output_path)

# %%
#!pip install rembg
# Out:
# Collecting rembg
#   Downloading rembg-2.0.59-py3-none-any.whl.metadata (17 kB)
# Collecting jsonschema (from rembg)
#   Downloading jsonschema-4.23.0-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy in c:\users\deniszelaya\anaconda3\envs\tf_gpu_env\lib\site-packages (from rembg) (1.24.4)
# Collecting onnxruntime (from rembg)
#   Downloading onnxruntime-1.19.2-cp38-cp38-win_amd64.whl.metadata (4.7 kB)
# Collecting opencv-python-headless (from rembg)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: pillow in c:\users\deniszelaya\anaconda3\envs\tf_gpu_env\lib\site-packages (from rembg) (10.4.0)
# Collecting pooch (from rembg)
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting pymatting (from rembg)
#   Downloading PyMatting-1.1.12-py3-none-any.whl.metadata (7.4 kB)
# Collecting scikit-image (from rembg)
#   Downloading scikit_image-0.21.0-cp38-cp38-win_amd64.whl.metadata (14 kB)
# Collecting scipy (from rembg)
#   Downloading scipy-1.10.1-cp38-cp38-win_amd64.whl.metadata (58 kB)
# Collecting tqdm (from rembg)
#   Downloading tqdm-4.67.0-py3-none-any.whl.metadata (57 kB)
# Collecting attrs>=22.2.0 (from jsonschema->rembg)
#   Downloading attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\deniszelaya\anaconda3\envs\tf_gpu_env\lib\site-packages (from jsonschema->rembg) (6.4.5)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema->rembg)
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting pkgutil-resolve-name>=1.3.10 (from jsonschema->rembg)
#   Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl.metadata (624 bytes)
# Collecting referencing>=0.28.4 (from jsonschema->rembg)
#   Downloading referencing-0.35.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema->rembg)
#   Downloading rpds_py-0.20.1-cp38-none-win_amd64.whl.metadata (4.2 kB)
# Collecting coloredlogs (from onnxruntime->rembg)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in c:\users\deniszelaya\anaconda3\envs\tf_gpu_env\lib\site-packages (from onnxruntime->rembg) (24.3.25)
# Requirement already satisfied: packaging in c:\users\deniszelaya\anaconda3\envs\tf_gpu_env\lib\site-packages (from onnxruntime->rembg) (24.1)
# Requirement already satisfied: protobuf in c:\users\deniszelaya\anaconda3\envs\tf_gpu_env\lib\site-packages (from onnxruntime->rembg) (3.19.6)
# Collecting sympy (from onnxruntime->rembg)
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\deniszelaya\anaconda3\envs\tf_gpu_env\lib\site-packages (from pooch->rembg) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in c:\users\deniszelaya\anaconda3\envs\tf_gpu_env\lib\site-packages (from pooch->rembg) (2.32.3)
# Collecting numba!=0.49.0 (from pymatting->rembg)
#   Downloading numba-0.58.1-cp38-cp38-win_amd64.whl.metadata (2.8 kB)
# Collecting networkx>=2.8 (from scikit-image->rembg)
#   Downloading networkx-3.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting imageio>=2.27 (from scikit-image->rembg)
#   Downloading imageio-2.35.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image->rembg)
#   Downloading tifffile-2023.7.10-py3-none-any.whl.metadata (31 kB)
# Collecting PyWavelets>=1.1.1 (from scikit-image->rembg)
#   Downloading PyWavelets-1.4.1-cp38-cp38-win_amd64.whl.metadata (1.9 kB)
# Collecting lazy_loader>=0.2 (from scikit-image->rembg)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: colorama in c:\users\deniszelaya\anaconda3\envs\tf_gpu_env\lib\site-packages (from tqdm->rembg) (0.4.6)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\deniszelaya\anaconda3\envs\tf_gpu_env\lib\site-packages (from importlib-resources>=1.4.0->jsonschema->rembg) (3.20.2)
# Collecting llvmlite<0.42,>=0.41.0dev0 (from numba!=0.49.0->pymatting->rembg)
#   Downloading llvmlite-0.41.1-cp38-cp38-win_amd64.whl.metadata (4.9 kB)
# Requirement already satisfied: importlib-metadata in c:\users\deniszelaya\anaconda3\envs\tf_gpu_env\lib\site-packages (from numba!=0.49.0->pymatting->rembg) (8.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\deniszelaya\anaconda3\envs\tf_gpu_env\lib\site-packages (from requests>=2.19.0->pooch->rembg) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deniszelaya\anaconda3\envs\tf_gpu_env\lib\site-packages (from requests>=2.19.0->pooch->rembg) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deniszelaya\anaconda3\envs\tf_gpu_env\lib\site-packages (from requests>=2.19.0->pooch->rembg) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deniszelaya\anaconda3\envs\tf_gpu_env\lib\site-packages (from requests>=2.19.0->pooch->rembg) (2024.8.30)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime->rembg)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->onnxruntime->rembg)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime->rembg)
#   Downloading pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Downloading rembg-2.0.59-py3-none-any.whl (39 kB)
# Downloading jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Downloading onnxruntime-1.19.2-cp38-cp38-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.1 MB 2.8 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/11.1 MB 3.2 MB/s eta 0:00:04
#    ------- -------------------------------- 2.1/11.1 MB 3.7 MB/s eta 0:00:03
#    ------------ --------------------------- 3.4/11.1 MB 4.4 MB/s eta 0:00:02
#    ----------------- ---------------------- 5.0/11.1 MB 5.1 MB/s eta 0:00:02
#    ------------------------ --------------- 6.8/11.1 MB 5.7 MB/s eta 0:00:01
#    ------------------------------- -------- 8.7/11.1 MB 6.3 MB/s eta 0:00:01
#    -------------------------------------- - 10.7/11.1 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 6.5 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    -- ------------------------------------- 2.4/38.8 MB 12.2 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.0/38.8 MB 11.6 MB/s eta 0:00:03
#    ------- -------------------------------- 7.3/38.8 MB 11.9 MB/s eta 0:00:03
#    ---------- ----------------------------- 9.7/38.8 MB 11.8 MB/s eta 0:00:03
#    ------------ --------------------------- 12.3/38.8 MB 11.9 MB/s eta 0:00:03
#    --------------- ------------------------ 14.7/38.8 MB 11.8 MB/s eta 0:00:03
#    ----------------- ---------------------- 17.0/38.8 MB 11.8 MB/s eta 0:00:02
#    -------------------- ------------------- 19.4/38.8 MB 11.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 21.8/38.8 MB 11.9 MB/s eta 0:00:02
#    ------------------------- -------------- 24.4/38.8 MB 11.9 MB/s eta 0:00:02
#    --------------------------- ------------ 26.7/38.8 MB 11.9 MB/s eta 0:00:02
#    ------------------------------ --------- 29.1/38.8 MB 11.8 MB/s eta 0:00:01
#    -------------------------------- ------- 31.5/38.8 MB 11.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.1/38.8 MB 11.8 MB/s eta 0:00:01
#    ------------------------------------- -- 36.7/38.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.8 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 11.5 MB/s eta 0:00:00
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
# Downloading PyMatting-1.1.12-py3-none-any.whl (52 kB)
# Downloading scipy-1.10.1-cp38-cp38-win_amd64.whl (42.2 MB)
#    ---------------------------------------- 0.0/42.2 MB ? eta -:--:--
#    -- ------------------------------------- 2.4/42.2 MB 12.2 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.7/42.2 MB 11.9 MB/s eta 0:00:04
#    ---- ----------------------------------- 5.2/42.2 MB 11.8 MB/s eta 0:00:04
#    -------- ------------------------------- 8.9/42.2 MB 11.1 MB/s eta 0:00:04
#    ---------- ----------------------------- 11.3/42.2 MB 11.4 MB/s eta 0:00:03
#    ------------- -------------------------- 13.9/42.2 MB 11.3 MB/s eta 0:00:03
#    --------------- ------------------------ 16.3/42.2 MB 11.5 MB/s eta 0:00:03
#    ----------------- ---------------------- 18.6/42.2 MB 11.5 MB/s eta 0:00:03
#    ------------------- -------------------- 21.0/42.2 MB 11.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 23.6/42.2 MB 11.6 MB/s eta 0:00:02
#    ------------------------ --------------- 26.0/42.2 MB 11.6 MB/s eta 0:00:02
#    -------------------------- ------------- 28.3/42.2 MB 11.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 30.7/42.2 MB 11.6 MB/s eta 0:00:01
#    ------------------------------- -------- 33.3/42.2 MB 11.6 MB/s eta 0:00:01
#    --------------------------------- ------ 35.7/42.2 MB 11.6 MB/s eta 0:00:01
#    ------------------------------------ --- 38.0/42.2 MB 11.6 MB/s eta 0:00:01
#    -------------------------------------- - 40.6/42.2 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 42.2/42.2 MB 11.3 MB/s eta 0:00:00
# Downloading scikit_image-0.21.0-cp38-cp38-win_amd64.whl (22.7 MB)
#    ---------------------------------------- 0.0/22.7 MB ? eta -:--:--
#    ---- ----------------------------------- 2.4/22.7 MB 11.2 MB/s eta 0:00:02
#    -------- ------------------------------- 4.7/22.7 MB 11.4 MB/s eta 0:00:02
#    ------------ --------------------------- 7.1/22.7 MB 11.8 MB/s eta 0:00:02
#    ----------------- ---------------------- 9.7/22.7 MB 11.6 MB/s eta 0:00:02
#    --------------------- ------------------ 12.1/22.7 MB 11.6 MB/s eta 0:00:01
#    ------------------------- -------------- 14.7/22.7 MB 11.7 MB/s eta 0:00:01
#    ------------------------------ --------- 17.0/22.7 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 19.4/22.7 MB 11.7 MB/s eta 0:00:01
#    ------------------------------------ --- 20.7/22.7 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  22.5/22.7 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------- 22.7/22.7 MB 10.8 MB/s eta 0:00:00
# Downloading tqdm-4.67.0-py3-none-any.whl (78 kB)
# Downloading attrs-24.2.0-py3-none-any.whl (63 kB)
# Downloading imageio-2.35.1-py3-none-any.whl (315 kB)
# Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 11.6 MB/s eta 0:00:00
# Downloading numba-0.58.1-cp38-cp38-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    ---------------------------------------  2.6/2.6 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 11.6 MB/s eta 0:00:00
# Downloading pkgutil_resolve_name-1.3.10-py3-none-any.whl (4.7 kB)
# Downloading PyWavelets-1.4.1-cp38-cp38-win_amd64.whl (4.2 MB)
#    ---------------------------------------- 0.0/4.2 MB ? eta -:--:--
#    ------------------------- -------------- 2.6/4.2 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------------- 4.2/4.2 MB 11.9 MB/s eta 0:00:00
# Downloading referencing-0.35.1-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.20.1-cp38-none-win_amd64.whl (218 kB)
# Downloading tifffile-2023.7.10-py3-none-any.whl (220 kB)
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    --------------- ------------------------ 2.4/6.2 MB 11.2 MB/s eta 0:00:01
#    ------------------------------ --------- 4.7/6.2 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 11.2 MB/s eta 0:00:00
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Downloading llvmlite-0.41.1-cp38-cp38-win_amd64.whl (28.1 MB)
#    ---------------------------------------- 0.0/28.1 MB ? eta -:--:--
#    --- ------------------------------------ 2.4/28.1 MB 11.2 MB/s eta 0:00:03
#    ------- -------------------------------- 5.0/28.1 MB 11.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 7.3/28.1 MB 11.6 MB/s eta 0:00:02
#    -------------- ------------------------- 10.0/28.1 MB 11.7 MB/s eta 0:00:02
#    ----------------- ---------------------- 12.3/28.1 MB 11.7 MB/s eta 0:00:02
#    --------------------- ------------------ 14.9/28.1 MB 11.7 MB/s eta 0:00:02
#    ------------------------ --------------- 17.3/28.1 MB 11.7 MB/s eta 0:00:01
#    --------------------------- ------------ 19.7/28.1 MB 11.7 MB/s eta 0:00:01
#    ------------------------------- -------- 22.3/28.1 MB 11.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 24.6/28.1 MB 11.7 MB/s eta 0:00:01
#    -------------------------------------- - 27.0/28.1 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 28.1/28.1 MB 11.4 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 8.8 MB/s eta 0:00:00
# Downloading pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Installing collected packages: mpmath, tqdm, tifffile, sympy, scipy, rpds-py, PyWavelets, pyreadline3, pkgutil-resolve-name, opencv-python-headless, networkx, llvmlite, lazy_loader, imageio, attrs, scikit-image, referencing, pooch, numba, humanfriendly, pymatting, jsonschema-specifications, coloredlogs, onnxruntime, jsonschema, rembg
# Successfully installed PyWavelets-1.4.1 attrs-24.2.0 coloredlogs-15.0.1 humanfriendly-10.0 imageio-2.35.1 jsonschema-4.23.0 jsonschema-specifications-2023.12.1 lazy_loader-0.4 llvmlite-0.41.1 mpmath-1.3.0 networkx-3.1 numba-0.58.1 onnxruntime-1.19.2 opencv-python-headless-4.10.0.84 pkgutil-resolve-name-1.3.10 pooch-1.8.2 pymatting-1.1.12 pyreadline3-3.5.4 referencing-0.35.1 rembg-2.0.59 rpds-py-0.20.1 scikit-image-0.21.0 scipy-1.10.1 sympy-1.13.3 tifffile-2023.7.10 tqdm-4.67.0
